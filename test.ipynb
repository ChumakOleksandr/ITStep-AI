# %% [markdown]
# <a href="https://colab.research.google.com/github/ChumakOleksandr/ITStep-AI/blob/superwised_learning/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

number = random.randint(1, 100)
print("Случайное число:", number)
# Out:
# Случайное число: 69
